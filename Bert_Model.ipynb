# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm
import os
from matplotlib import pyplot as plt
from sklearn.neighbors import KNeighborsRegressor
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import mean_squared_error
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.7/dist-packages (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from lightgbm) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->lightgbm) (1.0.1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import re
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras.models import Model

# %%
tf.keras.backend.clear_session()
max_seq_length = 150
input_word_ids = tf.keras.layers.Input(shape=(max_seq_length,), dtype=tf.int32, name="input_word_ids")
input_mask = tf.keras.layers.Input(shape=(max_seq_length,), dtype=tf.int32, name="input_mask")
segment_ids = tf.keras.layers.Input(shape=(max_seq_length,), dtype=tf.int32, name="segment_ids")
bert_layer = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/1", trainable=False)
pooled_output, sequence_output = bert_layer([input_word_ids, input_mask, segment_ids])
bert_model = Model(inputs=[input_word_ids, input_mask, segment_ids], outputs=pooled_output)

# %%
bert_model.summary()
#bert_model.output
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_word_ids (InputLayer)     [(None, 150)]        0
# __________________________________________________________________________________________________
# input_mask (InputLayer)         [(None, 150)]        0
# __________________________________________________________________________________________________
# segment_ids (InputLayer)        [(None, 150)]        0
# __________________________________________________________________________________________________
# keras_layer (KerasLayer)        [(None, 768), (None, 109482241   input_word_ids[0][0]
#                                                                  input_mask[0][0]
#                                                                  segment_ids[0][0]
# ==================================================================================================
# Total params: 109,482,241
# Trainable params: 0
# Non-trainable params: 109,482,241
# __________________________________________________________________________________________________

# %%
#getting Vocab file
vocab_file = bert_layer.resolved_object.vocab_file.asset_path.numpy()
do_lower_case = bert_layer.resolved_object.do_lower_case.numpy()

# %%
pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/ac/aa/1437691b0c7c83086ebb79ce2da16e00bef024f24fec2a5161c35476f499/sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 25.6MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.96

# %%
import tokenization
tokenizer = tokenization.FullTokenizer(vocab_file, do_lower_case)

# %%
def tokenize(data):
  data_tokens=[]
  data_mask=[]
  data_segment=[]
  max_len_limit=max_seq_length-2
  N=0
  for i in range(len(data.values)):
    tokens=tokenizer.tokenize(data.values[i])
    if len(tokens)>max_len_limit or len(tokens)==max_len_limit:
      tokens=tokens[0:max_seq_length-2]
      tokens=['[CLS]',*tokens,'[SEP]']
      data_mask.append(np.array([1]*len(tokens)))
    if len(tokens)<max_len_limit:
      data_mask.append(np.array([1]*(len(tokens)+2)+[0]*(max_seq_length-len(tokens)-2)))
      for i in range(max_seq_length-len(tokens)-2):
        N=N+1
        tokens.append('[PAD]')
      tokens=['[CLS]',*tokens,'[SEP]']
    data_tokens.append(tokenizer.convert_tokens_to_ids(tokens))
    data_segment.append(np.array([0]*max_seq_length))
  return np.asarray(data_tokens),np.asarray(data_mask),np.asarray(data_segment)

# %%
train_data = pd.read_csv('/content/drive/MyDrive/CS2/train.csv/train.csv')
test_data = pd.read_csv('/content/drive/MyDrive/CS2/test.csv')

# removing unused columns
train_data.drop(['url_legal', 'license','standard_error'], axis=1, inplace=True)
test_data.drop(['url_legal', 'license'], axis=1, inplace=True)

for i in range(len(train_data)):
  train_data['excerpt'][i]=re.sub('[^A-Za-z0-9]+', ' ', train_data['excerpt'][i]).strip()
for i in range(len(test_data)):
  test_data['excerpt'][i]=re.sub('[^A-Za-z0-9]+', ' ', test_data['excerpt'][i]).strip()

from sklearn.model_selection import train_test_split
X=train_data['excerpt']
y=train_data['target']
#x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.15,random_state=20)
#x_train, x_cv, y_train, y_cv = train_test_split(x_train, y_train, test_size=0.15,random_state=20)

# %%
x_td=test_data['excerpt']
X_td_tokens,X_td_mask,X_td_segment=tokenize(x_td)
X_td_pooled_output=bert_model.predict([X_td_tokens, X_td_mask, X_td_segment])

# %%
X_td_pooled_output.shape
# Out:
# (7, 768)

# %%
import numpy as np
from sklearn.model_selection import KFold
models_list=[]
kf=KFold(n_splits=5, random_state=None, shuffle=False)
for train_index, test_index in kf.split(X):
  x_train, x_cv = X[train_index], X[test_index]
  y_train, y_cv = y[train_index], y[test_index]
  X_train_tokens,X_train_mask,X_train_segment=tokenize(x_train)
  X_cv_tokens,X_cv_mask,X_cv_segment=tokenize(x_cv)
  X_train_pooled_output=bert_model.predict([X_train_tokens, X_train_mask, X_train_segment])
  X_cv_pooled_output=bert_model.predict([X_cv_tokens, X_cv_mask, X_cv_segment])
  from tensorflow.keras.layers import Input, Dense, Activation, Dropout
  from tensorflow.keras.models import Model
  from keras.callbacks import EarlyStopping,TensorBoard
  early_stop_1=EarlyStopping(monitor='val_root_mean_squared_error',patience=10,restore_best_weights=True)
  input_layer = Input(shape=(768,))
  layer1 = Dense(256,activation='relu',kernel_initializer=tf.keras.initializers.glorot_normal(seed=30))(input_layer)
  Dropout_layer_1=Dropout(0.)(layer1)
  layer2 = Dense(128,activation='relu',kernel_initializer=tf.keras.initializers.glorot_normal(seed=30))(Dropout_layer_1)
  Dropout_layer_2=Dropout(0.1)(layer2)
  layer3 = Dense(32,activation='relu',kernel_initializer=tf.keras.initializers.glorot_normal(seed=30))(Dropout_layer_2)
  output = Dense(1,activation='linear',kernel_initializer=tf.keras.initializers.glorot_normal(seed=0))(layer3)
  Model=Model(inputs=input_layer,outputs=output)
  rmse=tf.keras.metrics.RootMeanSquaredError()
  mse = tf.keras.losses.MeanSquaredError()
  Model.compile(optimizer='adam', loss=mse,metrics=[rmse])
  Model.fit(X_train_pooled_output,y_train,epochs=500, validation_data=(X_cv_pooled_output,y_cv), batch_size=10,verbose=2,callbacks=[early_stop_1])
  models_list.append(Model)
# Out:
# Epoch 1/500
# 227/227 - 1s - loss: 0.8248 - root_mean_squared_error: 0.9082 - val_loss: 0.7676 - val_root_mean_squared_error: 0.8762
# Epoch 2/500
# 227/227 - 1s - loss: 0.5518 - root_mean_squared_error: 0.7429 - val_loss: 0.5767 - val_root_mean_squared_error: 0.7594
# Epoch 3/500
# 227/227 - 1s - loss: 0.5482 - root_mean_squared_error: 0.7404 - val_loss: 0.5172 - val_root_mean_squared_error: 0.7192
# Epoch 4/500
# 227/227 - 1s - loss: 0.5283 - root_mean_squared_error: 0.7268 - val_loss: 0.4987 - val_root_mean_squared_error: 0.7062
# Epoch 5/500
# 227/227 - 1s - loss: 0.4833 - root_mean_squared_error: 0.6952 - val_loss: 0.5537 - val_root_mean_squared_error: 0.7441
# Epoch 6/500
# 227/227 - 1s - loss: 0.4894 - root_mean_squared_error: 0.6996 - val_loss: 0.5509 - val_root_mean_squared_error: 0.7422
# Epoch 7/500
# 227/227 - 1s - loss: 0.4805 - root_mean_squared_error: 0.6931 - val_loss: 0.5154 - val_root_mean_squared_error: 0.7179
# Epoch 8/500
# 227/227 - 1s - loss: 0.4788 - root_mean_squared_error: 0.6920 - val_loss: 0.5609 - val_root_mean_squared_error: 0.7489
# Epoch 9/500
# 227/227 - 1s - loss: 0.4560 - root_mean_squared_error: 0.6753 - val_loss: 0.5024 - val_root_mean_squared_error: 0.7088
# Epoch 10/500
# 227/227 - 1s - loss: 0.4715 - root_mean_squared_error: 0.6866 - val_loss: 0.4702 - val_root_mean_squared_error: 0.6857
# Epoch 11/500
# 227/227 - 1s - loss: 0.4525 - root_mean_squared_error: 0.6727 - val_loss: 0.5058 - val_root_mean_squared_error: 0.7112
# Epoch 12/500
# 227/227 - 1s - loss: 0.4437 - root_mean_squared_error: 0.6661 - val_loss: 0.5077 - val_root_mean_squared_error: 0.7125
# Epoch 13/500
# 227/227 - 1s - loss: 0.4599 - root_mean_squared_error: 0.6782 - val_loss: 0.4645 - val_root_mean_squared_error: 0.6815
# Epoch 14/500
# 227/227 - 1s - loss: 0.4247 - root_mean_squared_error: 0.6517 - val_loss: 0.4853 - val_root_mean_squared_error: 0.6966
# Epoch 15/500
# 227/227 - 1s - loss: 0.4414 - root_mean_squared_error: 0.6644 - val_loss: 0.5001 - val_root_mean_squared_error: 0.7072
# Epoch 16/500
# 227/227 - 1s - loss: 0.4378 - root_mean_squared_error: 0.6617 - val_loss: 0.6500 - val_root_mean_squared_error: 0.8062
# Epoch 17/500
# 227/227 - 1s - loss: 0.4278 - root_mean_squared_error: 0.6541 - val_loss: 0.4609 - val_root_mean_squared_error: 0.6789
# Epoch 18/500
# 227/227 - 1s - loss: 0.4340 - root_mean_squared_error: 0.6588 - val_loss: 0.4881 - val_root_mean_squared_error: 0.6986
# Epoch 19/500
# 227/227 - 1s - loss: 0.4360 - root_mean_squared_error: 0.6603 - val_loss: 0.4796 - val_root_mean_squared_error: 0.6925
# Epoch 20/500
# 227/227 - 1s - loss: 0.4127 - root_mean_squared_error: 0.6424 - val_loss: 0.5264 - val_root_mean_squared_error: 0.7255
# Epoch 21/500
# 227/227 - 1s - loss: 0.4184 - root_mean_squared_error: 0.6469 - val_loss: 0.4640 - val_root_mean_squared_error: 0.6811
# Epoch 22/500
# 227/227 - 1s - loss: 0.4126 - root_mean_squared_error: 0.6423 - val_loss: 0.4623 - val_root_mean_squared_error: 0.6799
# Epoch 23/500
# 227/227 - 1s - loss: 0.4133 - root_mean_squared_error: 0.6429 - val_loss: 0.4618 - val_root_mean_squared_error: 0.6796
# Epoch 24/500
# 227/227 - 1s - loss: 0.4044 - root_mean_squared_error: 0.6359 - val_loss: 0.4615 - val_root_mean_squared_error: 0.6793
# Epoch 25/500
# 227/227 - 1s - loss: 0.4021 - root_mean_squared_error: 0.6341 - val_loss: 0.4527 - val_root_mean_squared_error: 0.6728
# Epoch 26/500
# 227/227 - 1s - loss: 0.4093 - root_mean_squared_error: 0.6398 - val_loss: 0.5124 - val_root_mean_squared_error: 0.7158
# Epoch 27/500
# 227/227 - 1s - loss: 0.3974 - root_mean_squared_error: 0.6304 - val_loss: 0.4663 - val_root_mean_squared_error: 0.6829
# Epoch 28/500
# 227/227 - 1s - loss: 0.3939 - root_mean_squared_error: 0.6276 - val_loss: 0.4867 - val_root_mean_squared_error: 0.6976
# Epoch 29/500
# 227/227 - 1s - loss: 0.4137 - root_mean_squared_error: 0.6432 - val_loss: 0.4602 - val_root_mean_squared_error: 0.6784
# Epoch 30/500
# 227/227 - 1s - loss: 0.3876 - root_mean_squared_error: 0.6225 - val_loss: 0.4782 - val_root_mean_squared_error: 0.6915
# Epoch 31/500
# 227/227 - 1s - loss: 0.3882 - root_mean_squared_error: 0.6230 - val_loss: 0.4613 - val_root_mean_squared_error: 0.6792
# Epoch 32/500
# 227/227 - 1s - loss: 0.3856 - root_mean_squared_error: 0.6209 - val_loss: 0.4644 - val_root_mean_squared_error: 0.6814
# Epoch 33/500
# 227/227 - 1s - loss: 0.3874 - root_mean_squared_error: 0.6224 - val_loss: 0.4605 - val_root_mean_squared_error: 0.6786
# Epoch 34/500
# 227/227 - 1s - loss: 0.3975 - root_mean_squared_error: 0.6304 - val_loss: 0.4615 - val_root_mean_squared_error: 0.6793
# Epoch 35/500
# 227/227 - 1s - loss: 0.3789 - root_mean_squared_error: 0.6156 - val_loss: 0.4802 - val_root_mean_squared_error: 0.6930
# Epoch 1/500
# 227/227 - 1s - loss: 0.7666 - root_mean_squared_error: 0.8755 - val_loss: 0.5512 - val_root_mean_squared_error: 0.7424
# Epoch 2/500
# 227/227 - 1s - loss: 0.5905 - root_mean_squared_error: 0.7684 - val_loss: 0.5335 - val_root_mean_squared_error: 0.7304
# Epoch 3/500
# 227/227 - 1s - loss: 0.5316 - root_mean_squared_error: 0.7291 - val_loss: 0.5362 - val_root_mean_squared_error: 0.7323
# Epoch 4/500
# 227/227 - 1s - loss: 0.5069 - root_mean_squared_error: 0.7120 - val_loss: 0.4872 - val_root_mean_squared_error: 0.6980
# Epoch 5/500
# 227/227 - 1s - loss: 0.5139 - root_mean_squared_error: 0.7169 - val_loss: 0.5846 - val_root_mean_squared_error: 0.7646
# Epoch 6/500
# 227/227 - 1s - loss: 0.4982 - root_mean_squared_error: 0.7059 - val_loss: 0.5569 - val_root_mean_squared_error: 0.7463
# Epoch 7/500
# 227/227 - 0s - loss: 0.4750 - root_mean_squared_error: 0.6892 - val_loss: 0.5395 - val_root_mean_squared_error: 0.7345
# Epoch 8/500
# 227/227 - 1s - loss: 0.4878 - root_mean_squared_error: 0.6984 - val_loss: 0.4891 - val_root_mean_squared_error: 0.6994
# Epoch 9/500
# 227/227 - 1s - loss: 0.4650 - root_mean_squared_error: 0.6819 - val_loss: 0.4880 - val_root_mean_squared_error: 0.6986
# Epoch 10/500
# 227/227 - 1s - loss: 0.4533 - root_mean_squared_error: 0.6733 - val_loss: 0.4658 - val_root_mean_squared_error: 0.6825
# Epoch 11/500
# 227/227 - 1s - loss: 0.4808 - root_mean_squared_error: 0.6934 - val_loss: 0.4778 - val_root_mean_squared_error: 0.6912
# Epoch 12/500
# 227/227 - 1s - loss: 0.4527 - root_mean_squared_error: 0.6728 - val_loss: 0.5160 - val_root_mean_squared_error: 0.7184
# Epoch 13/500
# 227/227 - 1s - loss: 0.4443 - root_mean_squared_error: 0.6665 - val_loss: 0.5086 - val_root_mean_squared_error: 0.7131
# Epoch 14/500
# 227/227 - 1s - loss: 0.4436 - root_mean_squared_error: 0.6660 - val_loss: 0.4546 - val_root_mean_squared_error: 0.6742
# Epoch 15/500
# 227/227 - 1s - loss: 0.4507 - root_mean_squared_error: 0.6714 - val_loss: 0.4947 - val_root_mean_squared_error: 0.7033
# Epoch 16/500
# 227/227 - 1s - loss: 0.4237 - root_mean_squared_error: 0.6509 - val_loss: 0.6163 - val_root_mean_squared_error: 0.7851
# Epoch 17/500
# 227/227 - 1s - loss: 0.4225 - root_mean_squared_error: 0.6500 - val_loss: 0.4564 - val_root_mean_squared_error: 0.6756
# Epoch 18/500
# 227/227 - 1s - loss: 0.4328 - root_mean_squared_error: 0.6579 - val_loss: 0.4748 - val_root_mean_squared_error: 0.6890
# Epoch 19/500
# 227/227 - 1s - loss: 0.4256 - root_mean_squared_error: 0.6524 - val_loss: 0.6333 - val_root_mean_squared_error: 0.7958
# Epoch 20/500
# 227/227 - 1s - loss: 0.4263 - root_mean_squared_error: 0.6529 - val_loss: 0.5129 - val_root_mean_squared_error: 0.7161
# Epoch 21/500
# 227/227 - 1s - loss: 0.4239 - root_mean_squared_error: 0.6511 - val_loss: 0.4719 - val_root_mean_squared_error: 0.6870
# Epoch 22/500
# 227/227 - 1s - loss: 0.4170 - root_mean_squared_error: 0.6458 - val_loss: 0.4673 - val_root_mean_squared_error: 0.6836
# Epoch 23/500
# 227/227 - 1s - loss: 0.4230 - root_mean_squared_error: 0.6504 - val_loss: 0.4813 - val_root_mean_squared_error: 0.6937
# Epoch 24/500
# 227/227 - 1s - loss: 0.4088 - root_mean_squared_error: 0.6393 - val_loss: 0.4588 - val_root_mean_squared_error: 0.6773
# Epoch 1/500
# 227/227 - 1s - loss: 0.7959 - root_mean_squared_error: 0.8922 - val_loss: 0.4685 - val_root_mean_squared_error: 0.6845
# Epoch 2/500
# 227/227 - 0s - loss: 0.5992 - root_mean_squared_error: 0.7741 - val_loss: 0.7968 - val_root_mean_squared_error: 0.8926
# Epoch 3/500
# 227/227 - 1s - loss: 0.5431 - root_mean_squared_error: 0.7369 - val_loss: 1.1717 - val_root_mean_squared_error: 1.0825
# Epoch 4/500
# 227/227 - 1s - loss: 0.5354 - root_mean_squared_error: 0.7317 - val_loss: 0.7733 - val_root_mean_squared_error: 0.8794
# Epoch 5/500
# 227/227 - 1s - loss: 0.5010 - root_mean_squared_error: 0.7078 - val_loss: 0.4696 - val_root_mean_squared_error: 0.6852
# Epoch 6/500
# 227/227 - 1s - loss: 0.5045 - root_mean_squared_error: 0.7103 - val_loss: 0.7334 - val_root_mean_squared_error: 0.8564
# Epoch 7/500
# 227/227 - 1s - loss: 0.4776 - root_mean_squared_error: 0.6911 - val_loss: 0.4437 - val_root_mean_squared_error: 0.6661
# Epoch 8/500
# 227/227 - 1s - loss: 0.4762 - root_mean_squared_error: 0.6900 - val_loss: 0.4091 - val_root_mean_squared_error: 0.6396
# Epoch 9/500
# 227/227 - 1s - loss: 0.4717 - root_mean_squared_error: 0.6868 - val_loss: 0.6976 - val_root_mean_squared_error: 0.8352
# Epoch 10/500
# 227/227 - 1s - loss: 0.4731 - root_mean_squared_error: 0.6878 - val_loss: 0.5547 - val_root_mean_squared_error: 0.7448
# Epoch 11/500
# 227/227 - 1s - loss: 0.4617 - root_mean_squared_error: 0.6795 - val_loss: 0.4746 - val_root_mean_squared_error: 0.6889
# Epoch 12/500
# 227/227 - 1s - loss: 0.4630 - root_mean_squared_error: 0.6804 - val_loss: 0.5954 - val_root_mean_squared_error: 0.7716
# Epoch 13/500
# 227/227 - 1s - loss: 0.4535 - root_mean_squared_error: 0.6734 - val_loss: 0.4370 - val_root_mean_squared_error: 0.6610
# Epoch 14/500
# 227/227 - 1s - loss: 0.4535 - root_mean_squared_error: 0.6734 - val_loss: 0.7598 - val_root_mean_squared_error: 0.8717
# Epoch 15/500
# 227/227 - 1s - loss: 0.4457 - root_mean_squared_error: 0.6676 - val_loss: 0.4217 - val_root_mean_squared_error: 0.6494
# Epoch 16/500
# 227/227 - 1s - loss: 0.4355 - root_mean_squared_error: 0.6599 - val_loss: 0.4081 - val_root_mean_squared_error: 0.6388
# Epoch 17/500
# 227/227 - 1s - loss: 0.4462 - root_mean_squared_error: 0.6680 - val_loss: 0.4485 - val_root_mean_squared_error: 0.6697
# Epoch 18/500
# 227/227 - 1s - loss: 0.4377 - root_mean_squared_error: 0.6616 - val_loss: 0.4545 - val_root_mean_squared_error: 0.6742
# Epoch 19/500
# 227/227 - 1s - loss: 0.4311 - root_mean_squared_error: 0.6566 - val_loss: 0.4115 - val_root_mean_squared_error: 0.6415
# Epoch 20/500
# 227/227 - 1s - loss: 0.4223 - root_mean_squared_error: 0.6498 - val_loss: 0.4845 - val_root_mean_squared_error: 0.6961
# Epoch 21/500
# 227/227 - 1s - loss: 0.4270 - root_mean_squared_error: 0.6534 - val_loss: 0.4855 - val_root_mean_squared_error: 0.6968
# Epoch 22/500
# 227/227 - 1s - loss: 0.4299 - root_mean_squared_error: 0.6557 - val_loss: 0.4451 - val_root_mean_squared_error: 0.6672
# Epoch 23/500
# 227/227 - 1s - loss: 0.4136 - root_mean_squared_error: 0.6431 - val_loss: 0.4681 - val_root_mean_squared_error: 0.6842
# Epoch 24/500
# 227/227 - 1s - loss: 0.4348 - root_mean_squared_error: 0.6594 - val_loss: 0.4343 - val_root_mean_squared_error: 0.6590
# Epoch 25/500
# 227/227 - 1s - loss: 0.4245 - root_mean_squared_error: 0.6515 - val_loss: 0.4289 - val_root_mean_squared_error: 0.6549
# Epoch 26/500
# 227/227 - 1s - loss: 0.4127 - root_mean_squared_error: 0.6424 - val_loss: 0.4616 - val_root_mean_squared_error: 0.6794
# Epoch 1/500
# 227/227 - 1s - loss: 0.7648 - root_mean_squared_error: 0.8745 - val_loss: 0.9580 - val_root_mean_squared_error: 0.9788
# Epoch 2/500
# 227/227 - 1s - loss: 0.6144 - root_mean_squared_error: 0.7838 - val_loss: 0.5856 - val_root_mean_squared_error: 0.7652
# Epoch 3/500
# 227/227 - 1s - loss: 0.5309 - root_mean_squared_error: 0.7286 - val_loss: 0.5714 - val_root_mean_squared_error: 0.7559
# Epoch 4/500
# 227/227 - 1s - loss: 0.5187 - root_mean_squared_error: 0.7202 - val_loss: 0.5314 - val_root_mean_squared_error: 0.7290
# Epoch 5/500
# 227/227 - 1s - loss: 0.4924 - root_mean_squared_error: 0.7017 - val_loss: 0.5100 - val_root_mean_squared_error: 0.7142
# Epoch 6/500
# 227/227 - 1s - loss: 0.4826 - root_mean_squared_error: 0.6947 - val_loss: 0.5289 - val_root_mean_squared_error: 0.7272
# Epoch 7/500
# 227/227 - 1s - loss: 0.4753 - root_mean_squared_error: 0.6894 - val_loss: 0.5177 - val_root_mean_squared_error: 0.7195
# Epoch 8/500
# 227/227 - 1s - loss: 0.4615 - root_mean_squared_error: 0.6793 - val_loss: 0.6977 - val_root_mean_squared_error: 0.8353
# Epoch 9/500
# 227/227 - 1s - loss: 0.4687 - root_mean_squared_error: 0.6846 - val_loss: 0.4684 - val_root_mean_squared_error: 0.6844
# Epoch 10/500
# 227/227 - 1s - loss: 0.4591 - root_mean_squared_error: 0.6776 - val_loss: 0.4712 - val_root_mean_squared_error: 0.6865
# Epoch 11/500
# 227/227 - 1s - loss: 0.4422 - root_mean_squared_error: 0.6650 - val_loss: 0.5475 - val_root_mean_squared_error: 0.7400
# Epoch 12/500
# 227/227 - 1s - loss: 0.4552 - root_mean_squared_error: 0.6747 - val_loss: 0.4727 - val_root_mean_squared_error: 0.6875
# Epoch 13/500
# 227/227 - 1s - loss: 0.4483 - root_mean_squared_error: 0.6696 - val_loss: 0.5464 - val_root_mean_squared_error: 0.7392
# Epoch 14/500
# 227/227 - 1s - loss: 0.4516 - root_mean_squared_error: 0.6720 - val_loss: 0.5008 - val_root_mean_squared_error: 0.7077
# Epoch 15/500
# 227/227 - 1s - loss: 0.4359 - root_mean_squared_error: 0.6602 - val_loss: 0.4682 - val_root_mean_squared_error: 0.6843
# Epoch 16/500
# 227/227 - 1s - loss: 0.4430 - root_mean_squared_error: 0.6656 - val_loss: 0.4986 - val_root_mean_squared_error: 0.7061
# Epoch 17/500
# 227/227 - 1s - loss: 0.4229 - root_mean_squared_error: 0.6503 - val_loss: 0.5034 - val_root_mean_squared_error: 0.7095
# Epoch 18/500
# 227/227 - 1s - loss: 0.4284 - root_mean_squared_error: 0.6545 - val_loss: 0.4778 - val_root_mean_squared_error: 0.6912
# Epoch 19/500
# 227/227 - 1s - loss: 0.4360 - root_mean_squared_error: 0.6603 - val_loss: 0.4430 - val_root_mean_squared_error: 0.6656
# Epoch 20/500
# 227/227 - 1s - loss: 0.4280 - root_mean_squared_error: 0.6542 - val_loss: 0.5555 - val_root_mean_squared_error: 0.7453
# Epoch 21/500
# 227/227 - 1s - loss: 0.4137 - root_mean_squared_error: 0.6432 - val_loss: 0.4894 - val_root_mean_squared_error: 0.6996
# Epoch 22/500
# 227/227 - 1s - loss: 0.4163 - root_mean_squared_error: 0.6453 - val_loss: 0.4708 - val_root_mean_squared_error: 0.6861
# Epoch 23/500
# 227/227 - 1s - loss: 0.4095 - root_mean_squared_error: 0.6399 - val_loss: 0.4354 - val_root_mean_squared_error: 0.6598
# Epoch 24/500
# 227/227 - 1s - loss: 0.4056 - root_mean_squared_error: 0.6368 - val_loss: 0.4484 - val_root_mean_squared_error: 0.6696
# Epoch 25/500
# 227/227 - 1s - loss: 0.4103 - root_mean_squared_error: 0.6405 - val_loss: 0.4683 - val_root_mean_squared_error: 0.6843
# Epoch 26/500
# 227/227 - 1s - loss: 0.4038 - root_mean_squared_error: 0.6354 - val_loss: 0.5091 - val_root_mean_squared_error: 0.7135
# Epoch 27/500
# 227/227 - 1s - loss: 0.3943 - root_mean_squared_error: 0.6279 - val_loss: 0.4560 - val_root_mean_squared_error: 0.6753
# Epoch 28/500
# 227/227 - 1s - loss: 0.3950 - root_mean_squared_error: 0.6285 - val_loss: 0.4751 - val_root_mean_squared_error: 0.6893
# Epoch 29/500
# 227/227 - 1s - loss: 0.4100 - root_mean_squared_error: 0.6403 - val_loss: 0.4463 - val_root_mean_squared_error: 0.6681
# Epoch 30/500
# 227/227 - 1s - loss: 0.4087 - root_mean_squared_error: 0.6393 - val_loss: 0.4509 - val_root_mean_squared_error: 0.6715
# Epoch 31/500
# 227/227 - 1s - loss: 0.3915 - root_mean_squared_error: 0.6257 - val_loss: 0.4689 - val_root_mean_squared_error: 0.6848
# Epoch 32/500
# 227/227 - 1s - loss: 0.4104 - root_mean_squared_error: 0.6406 - val_loss: 0.6135 - val_root_mean_squared_error: 0.7833
# Epoch 33/500
# 227/227 - 1s - loss: 0.3991 - root_mean_squared_error: 0.6317 - val_loss: 0.4779 - val_root_mean_squared_error: 0.6913
# Epoch 1/500
# 227/227 - 1s - loss: 0.8166 - root_mean_squared_error: 0.9036 - val_loss: 0.5335 - val_root_mean_squared_error: 0.7304
# Epoch 2/500
# 227/227 - 1s - loss: 0.5819 - root_mean_squared_error: 0.7629 - val_loss: 0.5951 - val_root_mean_squared_error: 0.7714
# Epoch 3/500
# 227/227 - 1s - loss: 0.5459 - root_mean_squared_error: 0.7388 - val_loss: 0.5482 - val_root_mean_squared_error: 0.7404
# Epoch 4/500
# 227/227 - 1s - loss: 0.5054 - root_mean_squared_error: 0.7109 - val_loss: 0.5467 - val_root_mean_squared_error: 0.7394
# Epoch 5/500
# 227/227 - 1s - loss: 0.5099 - root_mean_squared_error: 0.7141 - val_loss: 0.4913 - val_root_mean_squared_error: 0.7009
# Epoch 6/500
# 227/227 - 1s - loss: 0.4929 - root_mean_squared_error: 0.7021 - val_loss: 0.4841 - val_root_mean_squared_error: 0.6958
# Epoch 7/500
# 227/227 - 1s - loss: 0.4829 - root_mean_squared_error: 0.6949 - val_loss: 0.5010 - val_root_mean_squared_error: 0.7078
# Epoch 8/500
# 227/227 - 1s - loss: 0.4722 - root_mean_squared_error: 0.6872 - val_loss: 0.4993 - val_root_mean_squared_error: 0.7066
# Epoch 9/500
# 227/227 - 1s - loss: 0.4661 - root_mean_squared_error: 0.6827 - val_loss: 0.6066 - val_root_mean_squared_error: 0.7789
# Epoch 10/500
# 227/227 - 1s - loss: 0.4548 - root_mean_squared_error: 0.6744 - val_loss: 0.4428 - val_root_mean_squared_error: 0.6654
# Epoch 11/500
# 227/227 - 1s - loss: 0.4576 - root_mean_squared_error: 0.6764 - val_loss: 0.4957 - val_root_mean_squared_error: 0.7040
# Epoch 12/500
# 227/227 - 1s - loss: 0.4414 - root_mean_squared_error: 0.6644 - val_loss: 0.4722 - val_root_mean_squared_error: 0.6872
# Epoch 13/500
# 227/227 - 1s - loss: 0.4336 - root_mean_squared_error: 0.6585 - val_loss: 0.4735 - val_root_mean_squared_error: 0.6881
# Epoch 14/500
# 227/227 - 1s - loss: 0.4426 - root_mean_squared_error: 0.6653 - val_loss: 0.4677 - val_root_mean_squared_error: 0.6839
# Epoch 15/500
# 227/227 - 1s - loss: 0.4291 - root_mean_squared_error: 0.6551 - val_loss: 0.4455 - val_root_mean_squared_error: 0.6674
# Epoch 16/500
# 227/227 - 1s - loss: 0.4263 - root_mean_squared_error: 0.6529 - val_loss: 0.4731 - val_root_mean_squared_error: 0.6878
# Epoch 17/500
# 227/227 - 1s - loss: 0.4318 - root_mean_squared_error: 0.6571 - val_loss: 0.4702 - val_root_mean_squared_error: 0.6857
# Epoch 18/500
# 227/227 - 1s - loss: 0.4294 - root_mean_squared_error: 0.6553 - val_loss: 0.4357 - val_root_mean_squared_error: 0.6600
# Epoch 19/500
# 227/227 - 1s - loss: 0.4225 - root_mean_squared_error: 0.6500 - val_loss: 0.4843 - val_root_mean_squared_error: 0.6959
# Epoch 20/500
# 227/227 - 1s - loss: 0.4115 - root_mean_squared_error: 0.6414 - val_loss: 0.5039 - val_root_mean_squared_error: 0.7098
# Epoch 21/500
# 227/227 - 1s - loss: 0.4160 - root_mean_squared_error: 0.6450 - val_loss: 0.4502 - val_root_mean_squared_error: 0.6710
# Epoch 22/500
# 227/227 - 1s - loss: 0.4217 - root_mean_squared_error: 0.6494 - val_loss: 0.4759 - val_root_mean_squared_error: 0.6899
# Epoch 23/500
# 227/227 - 1s - loss: 0.4222 - root_mean_squared_error: 0.6498 - val_loss: 0.4540 - val_root_mean_squared_error: 0.6738
# Epoch 24/500
# 227/227 - 1s - loss: 0.4160 - root_mean_squared_error: 0.6449 - val_loss: 0.5063 - val_root_mean_squared_error: 0.7116
# Epoch 25/500
# 227/227 - 1s - loss: 0.4191 - root_mean_squared_error: 0.6474 - val_loss: 0.4395 - val_root_mean_squared_error: 0.6630
# Epoch 26/500
# 227/227 - 1s - loss: 0.4186 - root_mean_squared_error: 0.6470 - val_loss: 0.4385 - val_root_mean_squared_error: 0.6622
# Epoch 27/500
# 227/227 - 1s - loss: 0.4177 - root_mean_squared_error: 0.6463 - val_loss: 0.4695 - val_root_mean_squared_error: 0.6852
# Epoch 28/500
# 227/227 - 1s - loss: 0.4048 - root_mean_squared_error: 0.6362 - val_loss: 0.4796 - val_root_mean_squared_error: 0.6925

# %% [markdown]
# #Predicting Test data

# %%
y_pred=np.zeros((X_td_pooled_output.shape[0],1))
for i in range(len(models_list)):
  y_pred=y_pred+models_list[i].predict(X_td_pooled_output)
y_pred=y_pred/len(models_list)
y_pred
# Out:
# array([[-1.25707645],
#        [-0.1196163 ],
#        [-0.61221824],
#        [-2.43381987],
#        [-1.55498238],
#        [-0.45163122],
#        [ 0.13068568]])

# %%
test_dat = pd.read_csv('../input/commonlitreadabilityprize/test.csv',index_col='id')
y_pred_pd=pd.DataFrame(y_pred_td,index=test_dat.index,columns=['target'])
y_pred_pd

#saving test data predicted
y_pred_pd.to_csv('./submission.csv')

# %%
#Score:0.645
